# %% [markdown]
# <a href="https://colab.research.google.com/github/kundanjungthapa/Data-Science/blob/main/Project_Data_Analysis_of_Natural_Disasters_in_Nepal_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font size=5 color="blue"><b><center> Disaster Statistics of Nepal: 2011 - 2023</center></b></font><br>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Context
# As a result of the terrain and climatic circumstances, Nepal is one of the most disaster-prone countries in the world. Earthquakes, landslides, floods, fires, and thunderbolts are the key disasters that have historically undermined the country's delicate ecosystem. These incidents not only cause the loss of life and property but also gravely imperil the physical infrastructure and obstruct economic development.

# %% [markdown]
# **1.1 Objective – Explore the dataset and extract insights from the data. Using statistical evidence to**
# - To analyze the loss of life and property due to different disasters.
# - To explore the economic impact of disasters in Nepal.
# - To analyze if the Earthquake of 2015 has increased the occurence of landslide in Nepal.
# - To understand the inter-relationship of different parameters concerning disastrous events in Nepal.

# %% [markdown]
# **1.2 Parameters**
# - Province :- Seven provinces of Nepal.
# - District :- All 77 districts of Nepal.
# - VDC/ Municipality:- Local government bodies.
# - Incident :- Typer of disaster Incident.
# - Incident date :- Reported date of incident.
# - Total Death :- Total deaths of the population.
# - Missing People: The number of people that are not confiremd dead and not found.
# - Affected Family :- Number of household affected by disaster.
# - Estimated Loss :- The loss of property measured in terms of Nepalese Rupees.
# - Injured :- Number of injured people.
# - Houses Fully Damaged​ :- The number of houses that are declared unlivable and must be torn down.
# - Houses Partially Damaged :- The number of houses that are livable after repair and maintenance.
# - Office :- The office reporting the disastrous events.

# %% [markdown]
# # 2. Libraries

# %%
### IMPORT: ------------------------------------
import scipy.stats as stats #It has all the probability distributions available along with many statistical functions.
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks
# %matplotlib inline

import seaborn as sns
import warnings
warnings.filterwarnings('ignore') # To supress warnings
sns.set(style="darkgrid") # set the background for the graphs

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # 3. Reading and Preparing Data for Analysis

# %%
#Reading the csv file Car details v3.csv
df = pd.read_csv('/content/drive/MyDrive/Data Science 6.30/Project/incident_report.csv')
disaster_data=df.copy()
disaster_data.head(5)
# Out:
#    S.No.     District VDC/Municipality Ward No. Incident Place Incident Date  \
# 0     11    Kathmandu                -      NaN            NaN     4/14/2011
# 1     12      Sunsari                -      NaN            NaN     4/14/2011
# 2     13     Dhankuta           Leguwa      NaN            NaN     4/14/2011
# 3     14  Nawalparasi                -      NaN            NaN     4/15/2011
# 4     15     Udayapur                -      NaN            NaN     4/15/2011
#
#       Incident  Death Male  Death Female  Death Unknown  ...  \
# 0         Fire           0             0              0  ...
# 1        storm           0             0              0  ...
# 2  Thunderbolt           0             0              0  ...
# 3         Fire           0             0              0  ...
# 4         Fire           0             0              0  ...
#
#    Private House Fully Damaged  Private House Partially Damaged  \
# 0                            0                                1
# 1                            0                                0
# 2                            0                                0
# 3                            1                                0
# 4                            2                                0
#
#    Displaced Male(N/A)  Displaced Female(N/A)  Property Loss  \
# 0                    0                      0            NaN
# 1                    0                      0            NaN
# 2                    0                      0            NaN
# 3                    0                      0            NaN
# 4                    0                      0            NaN
#
#    No. of Displaced Family  Cattles Loss  Displaced Shed              Source  \
# 0                        0             0               0        Nepal Police
# 1                        0             0               0  Armed Police Force
# 2                        0             0               0       DAO, Dhankuta
# 3                        0             0               0  Armed Police Force
# 4                        0             0               0  Armed Police Force
#
#                                Remarks
# 0  Gyanendra Raj Sakya,Gopal Bhattarai
# 1                                  NaN
# 2                                  NaN
# 3                       Mahadev Thakur
# 4                      Dinesh Shrestha
#
# [5 rows x 27 columns]

# %%
print(disaster_data.info())
print('**********************************************************\n**********************************************************')
print(disaster_data.describe(include = 'object'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36347 entries, 0 to 36346
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   S.No.                            36347 non-null  int64
#  1   District                         36345 non-null  object
#  2   VDC/Municipality                 36347 non-null  object
#  3   Ward No.                         28692 non-null  object
#  4   Incident Place                   17115 non-null  object
#  5   Incident Date                    36347 non-null  object
#  6   Incident                         36347 non-null  object
#  7   Death Male                       36347 non-null  int64
#  8   Death Female                     36347 non-null  int64
#  9   Death Unknown                    36347 non-null  int64
#  10  Total Death                      36347 non-null  int64
#  11  Missing People                   36347 non-null  int64
#  12  Affected Family                  36347 non-null  int64
#  13  Estimated Loss                   21685 non-null  float64
#  14  Injured                          36347 non-null  int64
#  15  Govt. Houses Fully Damaged       36347 non-null  int64
#  16  Govt. Houses Partially Damaged   36347 non-null  int64
#  17  Private House Fully Damaged      36347 non-null  int64
#  18  Private House Partially Damaged  36347 non-null  int64
#  19  Displaced Male(N/A)              36347 non-null  int64
#  20  Displaced Female(N/A)            36347 non-null  int64
#  21  Property Loss                    30067 non-null  float64
#  22  No. of Displaced Family          36347 non-null  int64
#  23  Cattles Loss                     36347 non-null  int64
#  24  Displaced Shed                   36347 non-null  int64
#  25  Source                           36004 non-null  object
#  26  Remarks                          34857 non-null  object
# dtypes: float64(2), int64(17), object(8)
# memory usage: 7.5+ MB
# None
# **********************************************************
# **********************************************************
#          District VDC/Municipality Ward No. Incident Place Incident Date  \
# count       36345            36347    28692          17115         36347
# unique         79             2999      112          13764          4302
# top     Kathmandu                -        1      Nayabasti     8/12/2017
# freq         1764             2727     2888             23           150
#
#        Incident        Source    Remarks
# count     36347         36004      34857
# unique       26           275      30725
# top        Fire  Nepal Police  Road Side
# freq      22674         29850        212

# %% [markdown]
# **From above tables it is clear that some of the columns have null data; dates are not in numerical terms; there are a number of unnecessary datasets for our analysis.
#
# **So, we clear unnecessary columns and values.**

# %%
# Removing unneccasry columns
disaster_data = disaster_data.drop(['S.No.','Ward No.','Death Male','Death Female','Death Unknown', 'VDC/Municipality','Incident Place','Property Loss','Displaced Male(N/A)','Displaced Female(N/A)','Remarks', 'Source'], axis=1)
disaster_data.dropna
# Dropping null values in reference to dataset in 'District' column
disaster_data.dropna(subset = ['Estimated Loss'], inplace=True)
disaster_data.dropna(subset = ['District'], inplace=True)
disaster_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21684 entries, 0 to 36346
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   District                         21684 non-null  object
#  1   Incident Date                    21684 non-null  object
#  2   Incident                         21684 non-null  object
#  3   Total Death                      21684 non-null  int64
#  4   Missing People                   21684 non-null  int64
#  5   Affected Family                  21684 non-null  int64
#  6   Estimated Loss                   21684 non-null  float64
#  7   Injured                          21684 non-null  int64
#  8   Govt. Houses Fully Damaged       21684 non-null  int64
#  9   Govt. Houses Partially Damaged   21684 non-null  int64
#  10  Private House Fully Damaged      21684 non-null  int64
#  11  Private House Partially Damaged  21684 non-null  int64
#  12  No. of Displaced Family          21684 non-null  int64
#  13  Cattles Loss                     21684 non-null  int64
#  14  Displaced Shed                   21684 non-null  int64
# dtypes: float64(1), int64(11), object(3)
# memory usage: 2.6+ MB

# %%
disaster_data.isnull().sum().values.sum()
# Out:
# 0

# %% [markdown]
# ** Further checking after performing necessary changes to the dataset.

# %%
disaster_data.describe()
# Out:
#         Total Death  Missing People  Affected Family  Estimated Loss  \
# count  21684.000000    21684.000000     21684.000000    2.168400e+04
# mean       0.453468        0.018816         3.396606    2.107875e+06
# std       27.938414        1.179431       145.129275    7.468852e+07
# min        0.000000        0.000000        -2.000000    0.000000e+00
# 25%        0.000000        0.000000         1.000000    1.000000e+05
# 50%        0.000000        0.000000         1.000000    2.500000e+05
# 75%        0.000000        0.000000         1.000000    6.540000e+05
# max     3570.000000      139.000000     17376.000000    1.005285e+10
#
#             Injured  Govt. Houses Fully Damaged  \
# count  21684.000000                21684.000000
# mean       1.118244                    0.124239
# std       62.784072                    6.561447
# min       -2.000000                   -1.000000
# 25%        0.000000                    0.000000
# 50%        0.000000                    0.000000
# 75%        0.000000                    0.000000
# max     7950.000000                  710.000000
#
#        Govt. Houses Partially Damaged  Private House Fully Damaged  \
# count                    21684.000000                 21684.000000
# mean                         0.175383                    36.951393
# std                          6.404748                  1477.724283
# min                         -1.000000                    -1.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                          0.000000                     1.000000
# max                        684.000000                 89884.000000
#
#        Private House Partially Damaged  No. of Displaced Family  Cattles Loss  \
# count                     21684.000000             21684.000000  21684.000000
# mean                         15.311382                 0.000092      1.075401
# std                         530.279116                 0.009604     30.321656
# min                           0.000000                 0.000000     -2.000000
# 25%                           0.000000                 0.000000      0.000000
# 50%                           0.000000                 0.000000      0.000000
# 75%                           0.000000                 0.000000      0.000000
# max                       55131.000000                 1.000000   2000.000000
#
#        Displaced Shed
# count    21684.000000
# mean         0.305202
# std          2.058927
# min         -2.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        181.000000

# %% [markdown]
# ** In the above description, coluns like 'Affected family', 'Injured', 'Govt. Houses Fully Damaged',	'Govt. Houses Partially Damaged',	'Private House Fully Damaged','Displaced Shed' and 'Cattle loss' have negative values, a misrepresentation of loss in numerical terms but not incorrect.
# ** Transforming negative values to positive.

# %%
# Changing negative values to absolute values
disaster_data['Affected Family'] = disaster_data['Affected Family'].abs()
disaster_data['Injured'] = disaster_data['Injured'].abs()
disaster_data['Govt. Houses Fully Damaged'] = disaster_data['Govt. Houses Fully Damaged'].abs()
disaster_data['Govt. Houses Partially Damaged'] = disaster_data['Govt. Houses Partially Damaged'].abs()
disaster_data['Private House Fully Damaged'] = disaster_data['Private House Fully Damaged'].abs()
disaster_data['Cattles Loss'] = disaster_data['Cattles Loss'].abs()
disaster_data['Displaced Shed'] = disaster_data['Displaced Shed'].abs()
disaster_data.describe()
# Out:
#         Total Death  Missing People  Affected Family  Estimated Loss  \
# count  21684.000000    21684.000000     21684.000000    2.168400e+04
# mean       0.453468        0.018816         3.397344    2.107875e+06
# std       27.938414        1.179431       145.129257    7.468852e+07
# min        0.000000        0.000000         0.000000    0.000000e+00
# 25%        0.000000        0.000000         1.000000    1.000000e+05
# 50%        0.000000        0.000000         1.000000    2.500000e+05
# 75%        0.000000        0.000000         1.000000    6.540000e+05
# max     3570.000000      139.000000     17376.000000    1.005285e+10
#
#             Injured  Govt. Houses Fully Damaged  \
# count  21684.000000                21684.000000
# mean       1.118428                    0.124331
# std       62.784068                    6.561445
# min        0.000000                    0.000000
# 25%        0.000000                    0.000000
# 50%        0.000000                    0.000000
# 75%        0.000000                    0.000000
# max     7950.000000                  710.000000
#
#        Govt. Houses Partially Damaged  Private House Fully Damaged  \
# count                    21684.000000                 21684.000000
# mean                         0.175475                    36.951577
# std                          6.404746                  1477.724278
# min                          0.000000                     0.000000
# 25%                          0.000000                     0.000000
# 50%                          0.000000                     0.000000
# 75%                          0.000000                     1.000000
# max                        684.000000                 89884.000000
#
#        Private House Partially Damaged  No. of Displaced Family  Cattles Loss  \
# count                     21684.000000             21684.000000  21684.000000
# mean                         15.311382                 0.000092      1.075586
# std                         530.279116                 0.009604     30.321650
# min                           0.000000                 0.000000      0.000000
# 25%                           0.000000                 0.000000      0.000000
# 50%                           0.000000                 0.000000      0.000000
# 75%                           0.000000                 0.000000      0.000000
# max                       55131.000000                 1.000000   2000.000000
#
#        Displaced Shed
# count    21684.000000
# mean         0.305571
# std          2.058873
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max        181.000000

# %%
disaster_data.describe(include = 'object')
# Out:
#        District Incident Date Incident
# count     21684         21684    21684
# unique       79          4097       17
# top      Morang     4/25/2015     Fire
# freq       1347            75    17787

# %% [markdown]
# **Now we have to add following columns based on existing columns.**
# 1. Province -Among the seven provinces(Koshi, Madhesh, Bagmati,Gandaki, Lumbini, Karnali and Sudurpaschim).
# 2. Year (of Incidence): From 2015 to 2023.
# 3. Season - Based on months
# (Spring: March-May,  Summer:(June-August),  Autumn: (September-November),  Winter: (December-February))
# 4. Fully damaged houses: merge government and private houses
# 5. Partially damaged houses: merge government and private houses
# 6. Reclassifying the disasters by focusing more on Earthquake, Landslide, Flood, Fire and Thunderbolt, and other disasters in 'other' category.

# %%
disaster_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21684 entries, 0 to 36346
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   District                         21684 non-null  object
#  1   Incident Date                    21684 non-null  object
#  2   Incident                         21684 non-null  object
#  3   Total Death                      21684 non-null  int64
#  4   Missing People                   21684 non-null  int64
#  5   Affected Family                  21684 non-null  int64
#  6   Estimated Loss                   21684 non-null  float64
#  7   Injured                          21684 non-null  int64
#  8   Govt. Houses Fully Damaged       21684 non-null  int64
#  9   Govt. Houses Partially Damaged   21684 non-null  int64
#  10  Private House Fully Damaged      21684 non-null  int64
#  11  Private House Partially Damaged  21684 non-null  int64
#  12  No. of Displaced Family          21684 non-null  int64
#  13  Cattles Loss                     21684 non-null  int64
#  14  Displaced Shed                   21684 non-null  int64
# dtypes: float64(1), int64(11), object(3)
# memory usage: 2.6+ MB

# %%
print(disaster_data.shape,'\n\n')

print(disaster_data.isnull().sum())
# Out:
# (21684, 15)
#
#
# District                           0
# Incident Date                      0
# Incident                           0
# Total Death                        0
# Missing People                     0
# Affected Family                    0
# Estimated Loss                     0
# Injured                            0
# Govt. Houses Fully Damaged         0
# Govt. Houses Partially Damaged     0
# Private House Fully Damaged        0
# Private House Partially Damaged    0
# No. of Displaced Family            0
# Cattles Loss                       0
# Displaced Shed                     0
# dtype: int64

# %%
# 1. Reclassifying districts based on Provine.
provinces_and_districts = {
    'Koshi': ['Bhojpur', 'Dhankuta', 'Ilam','Jhapa','Khotang','Morang','Okhaldhunga','Panchthar','Shankhuwasabha', 'Solukhumbu','Sunsari','Taplejung', 'Terhathum','Udayapur'],
    'Madhesh': ['Bara', 'Dhanusha', 'Mahottari','Parsa', 'Rautahat','Saptari', 'Sarlahi','Siraha'],
    'Bagmati': ['Bhaktapur', 'Chitawan','Dhading','Dolakha','Kathmandu','Kavrepalanchowk' ,'Lalitpur','Makawanpur','Nuwakot','Ramechhap','Rasuwa','Sindhuli','Sindhupalchowk'],
    'Gandaki': ['Baglung','Gorkha', 'Kaski', 'Lamjung','Manang','Mustang','Myagdi','Nawalparasi','Nawalparasi (Bardghat Susta East)','Parbat','Shyanja', 'Tanahu'],
    'Lumbini': ['Arghakhanchi','Banke','Bardiya','Dang','Gulmi','Kapilbastu', 'Nawalparasi (Bardghat Susta West)','Palpa','Pyuthan','Rolpa','Rukum','Rukum East', 'Rupandehi'],
    'Karnali': ['Dailekh','Dolpa','Humla', 'Jajarkot','Jumla','Kalikot','Mugu','Rukum West','Salyan', 'Surkhet'],
    'Sudurpashchim': ['Achhaam','Baitadi', 'Bajhang', 'Bajura', 'Dadeldhura', 'Darchula','Doti', 'Kailali', 'Kanchanpur']
}

def get_province(district):
  for province, districts in provinces_and_districts.items():
        if district in districts:
            return province
disaster_data['province'] = disaster_data['District'].apply(lambda x:get_province(x))

# 2. Extracting year of incident and typecasting it
disaster_data['incident_year'] = disaster_data['Incident Date'].apply(lambda x: x[-4:])
disaster_data.incident_year = disaster_data['incident_year'].astype("int")

# 3. Transforming the month of occurence data into its corresponding season as per Nepal's climate.
season_name = {
    'Spring': [3, 4, 5],    # March-May
    'Summer': [6, 7, 8],    # June-August
    'Autumn': [9, 10, 11],  # September-November
    'Winter': [12, 1, 2]    # December-February
}

def get_season(month):
  for season, months in season_name.items():
        if month in months:
            return season

disaster_data['incident_month'] = disaster_data['Incident Date'].apply(lambda x: x[0:x.index('/')])
disaster_data.incident_month = disaster_data['incident_month'].astype("int")
disaster_data['season'] = disaster_data['incident_month'].apply(lambda x:get_season(x))


# 4. Creating summed value for Fully damaged houses by merging government and private houses
disaster_data['houses_fully_destroyed'] = disaster_data['Govt. Houses Fully Damaged']+disaster_data['Private House Fully Damaged']

# 5. Creating summed value for Partially damaged houses by merging government and private houses
disaster_data['houses_partially_destroyed'] = disaster_data['Govt. Houses Partially Damaged']+disaster_data['Private House Partially Damaged']

# 6. Reclassifying the disaster names with more focus on Earthquake, Landslide, Flood, Fire and Thunderbolt

disaster_cat = ['Earthquake','Flood','Fire','Landslide','Thunderbolt']

def get_disaster(disaster):
    for disaster_type in disaster_cat:
        if disaster == disaster_type:
          return disaster
        elif disaster == 'Flash Flood':
          return 'Flood'
        elif disaster == 'Forest Fire':
          return 'Fire'
    return 'Other'

disaster_data['Disaster'] = disaster_data['Incident'].apply(lambda x:get_disaster(x))

disaster_data.head(5)
# Out:
#     District Incident Date     Incident  Total Death  Missing People  \
# 0  Kathmandu     4/14/2011         Fire            0               0
# 1    Sunsari     4/14/2011        storm            0               0
# 2   Dhankuta     4/14/2011  Thunderbolt            0               0
# 5  Mahottari     4/16/2011         Fire            0               0
# 6    Bardiya     4/17/2011         Fire            0               0
#
#    Affected Family  Estimated Loss  Injured  Govt. Houses Fully Damaged  \
# 0                2         50000.0        0                           0
# 1                0       7000000.0        0                           0
# 2                0        100000.0        0                           0
# 5                1        150000.0        0                           0
# 6                0        150000.0        1                           0
#
#    Govt. Houses Partially Damaged  ...  No. of Displaced Family  Cattles Loss  \
# 0                               0  ...                        0             0
# 1                               0  ...                        0             0
# 2                               0  ...                        0             0
# 5                               0  ...                        0             0
# 6                               0  ...                        0             0
#
#    Displaced Shed  province  incident_year incident_month  season  \
# 0               0   Bagmati           2011              4  Spring
# 1               0     Koshi           2011              4  Spring
# 2               0     Koshi           2011              4  Spring
# 5               0   Madhesh           2011              4  Spring
# 6               0   Lumbini           2011              4  Spring
#
#    houses_fully_destroyed houses_partially_destroyed     Disaster
# 0                       0                          1         Fire
# 1                       0                          0        Other
# 2                       0                          0  Thunderbolt
# 5                       1                          0         Fire
# 6                       0                          0         Fire
#
# [5 rows x 22 columns]

# %%
# Dropping unnecessary values and changing type of data set to 'category' to save memory
disaster_data = disaster_data.drop(['Incident','Incident Date','Govt. Houses Fully Damaged','Injured','Private House Partially Damaged','Private House Fully Damaged','Govt. Houses Partially Damaged','incident_month','Missing People', 'No. of Displaced Family','Cattles Loss','Displaced Shed'], axis=1)
disaster_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21684 entries, 0 to 36346
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   District                    21684 non-null  object
#  1   Total Death                 21684 non-null  int64
#  2   Affected Family             21684 non-null  int64
#  3   Estimated Loss              21684 non-null  float64
#  4   province                    21684 non-null  object
#  5   incident_year               21684 non-null  int64
#  6   season                      21684 non-null  object
#  7   houses_fully_destroyed      21684 non-null  int64
#  8   houses_partially_destroyed  21684 non-null  int64
#  9   Disaster                    21684 non-null  object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.8+ MB

# %%
# Reorganizing the order of dataset
new_order = ['Disaster','province','District', 'incident_year','season','Total Death','Estimated Loss','Affected Family','houses_fully_destroyed','houses_partially_destroyed']
disaster_data = disaster_data.reindex(columns=new_order)
print(disaster_data.info(),'\n\n\n')
print(disaster_data.isnull().sum(),'\n\n\n')
print(disaster_data.nunique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21684 entries, 0 to 36346
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Disaster                    21684 non-null  object
#  1   province                    21684 non-null  object
#  2   District                    21684 non-null  object
#  3   incident_year               21684 non-null  int64
#  4   season                      21684 non-null  object
#  5   Total Death                 21684 non-null  int64
#  6   Estimated Loss              21684 non-null  float64
#  7   Affected Family             21684 non-null  int64
#  8   houses_fully_destroyed      21684 non-null  int64
#  9   houses_partially_destroyed  21684 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.8+ MB
# None
#
#
#
# Disaster                      0
# province                      0
# District                      0
# incident_year                 0
# season                        0
# Total Death                   0
# Estimated Loss                0
# Affected Family               0
# houses_fully_destroyed        0
# houses_partially_destroyed    0
# dtype: int64
#
#
#
# Disaster                         6
# province                         7
# District                        79
# incident_year                   13
# season                           4
# Total Death                     32
# Estimated Loss                2067
# Affected Family                 88
# houses_fully_destroyed         114
# houses_partially_destroyed     107
# dtype: int64

# %% [markdown]
# **Types of variables**
#
# - Categorical varibles - Disaster, Province, Season, Indcident year.
# -  Quantitative variables -Deaths, missing people, injured,estimated loss,number of displaced family, houses fully destroyed, houses partially destroyed, cattle loss and displaced shed.
#
# Here, only incident year can be used as discrete values while others will be converted to continuous values for further analysis.
#
# - There are no missing values

# %%
# creating new csv file
# disaster_data.to_csv('/content/drive/MyDrive/Data Science 6.30/Project/cleaned_disaster_data.csv')

# %% [markdown]
# # 4. Categorizing the preferences for dataset

# %%
disaster_data.province = disaster_data['province'].astype("category")
disaster_data.Disaster = disaster_data['Disaster'].astype("category")
disaster_data.season = disaster_data['season'].astype("category")
disaster_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21684 entries, 0 to 36346
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Disaster                    21684 non-null  category
#  1   province                    21684 non-null  category
#  2   District                    21684 non-null  object
#  3   incident_year               21684 non-null  int64
#  4   season                      21684 non-null  category
#  5   Total Death                 21684 non-null  int64
#  6   Estimated Loss              21684 non-null  float64
#  7   Affected Family             21684 non-null  int64
#  8   houses_fully_destroyed      21684 non-null  int64
#  9   houses_partially_destroyed  21684 non-null  int64
# dtypes: category(3), float64(1), int64(5), object(1)
# memory usage: 1.4+ MB

# %%
#get the size of dataframe
print ("Rows     : " , disaster_data.shape[0])
print ("Columns  : " , disaster_data.shape[1])

print ("\nValues : \n", disaster_data.values)
print ("\nFeatures : \n", list(disaster_data.columns))
#print ("\nFeatures : \n", list(disaster_data.columns.to_list()))
# Out:
# Rows     :  21684
# Columns  :  10
#
# Values :
#  [['Fire' 'Bagmati' 'Kathmandu' ... 2 0 1]
#  ['Other' 'Koshi' 'Sunsari' ... 0 0 0]
#  ['Thunderbolt' 'Koshi' 'Dhankuta' ... 0 0 0]
#  ...
#  ['Fire' 'Bagmati' 'Kathmandu' ... 1 0 0]
#  ['Fire' 'Madhesh' 'Saptari' ... 1 0 0]
#  ['Fire' 'Koshi' 'Morang' ... 1 0 0]]
#
# Features :
#  ['Disaster', 'province', 'District', 'incident_year', 'season', 'Total Death', 'Estimated Loss', 'Affected Family', 'houses_fully_destroyed', 'houses_partially_destroyed']

# %%
disaster_data.describe()
# Out:
#        incident_year   Total Death  Estimated Loss  Affected Family  \
# count   21684.000000  21684.000000    2.168400e+04     21684.000000
# mean     2018.369996      0.453468    2.107875e+06         3.397344
# std         3.360262     27.938414    7.468852e+07       145.129257
# min      2011.000000      0.000000    0.000000e+00         0.000000
# 25%      2016.000000      0.000000    1.000000e+05         1.000000
# 50%      2019.000000      0.000000    2.500000e+05         1.000000
# 75%      2021.000000      0.000000    6.540000e+05         1.000000
# max      2023.000000   3570.000000    1.005285e+10     17376.000000
#
#        houses_fully_destroyed  houses_partially_destroyed
# count            21684.000000                21684.000000
# mean                37.075909                   15.486857
# std               1482.503752                  533.415950
# min                  0.000000                    0.000000
# 25%                  0.000000                    0.000000
# 50%                  0.000000                    0.000000
# 75%                  1.000000                    0.000000
# max              90594.000000                55427.000000

# %% [markdown]
# **Observations**
#  - Average year of occurence of disaster is 2019.69, meaning most disasters have been in the year 2019.
#  - There is huge skewness in data such as Total deaths,estimated loss,affected family, and houses fully/partially destroyed.
#  - This is an indication that a large number of events have zero values and very few have postive integers with large values.

# %%
disaster_data.describe(include='category')
# Out:
#        Disaster province  season
# count     21684    21684   21684
# unique        6        7       4
# top        Fire    Koshi  Spring
# freq      17809     6568    7941

# %%
list_col=  disaster_data.select_dtypes(['category']).columns
list_col
# Out:
# Index(['Disaster', 'province', 'season'], dtype='object')

# %%
# get counts of unique observations for each category variable
list_col=  disaster_data.select_dtypes(['category']).columns
for i in range(len(list_col)):
    print(disaster_data[list_col[i]].value_counts(),'\n\n')
# Out:
# Fire           17809
# Other           2196
# Landslide        711
# Thunderbolt      554
# Flood            332
# Earthquake        82
# Name: Disaster, dtype: int64
#
#
# Koshi            6568
# Madhesh          5445
# Lumbini          3445
# Bagmati          3343
# Gandaki          1170
# Sudurpashchim    1123
# Karnali           590
# Name: province, dtype: int64
#
#
# Spring    7941
# Winter    5425
# Summer    4586
# Autumn    3732
# Name: season, dtype: int64

# %% [markdown]
# **Observations**
# - The results indicate that the occurence of fire disasters is six times greater than all the other disasters combined.
# - Koshi Province has recorded the higest number of disastrous events.
# - There is also large variation in seasonal occurences of disasters which may indicate that Nepal is indeed affected by seasonal disasters.

# %% [markdown]
# # ****Exploratory Data Analysis****

# %% [markdown]
# ## Univariate Analysis

# %%
# No. of disasters: pie plot
df_sym = pd.DataFrame(disaster_data['Disaster'].value_counts())
print(df_sym)

print(df_sym.index.values)
df_sym.plot.pie(subplots=True,labels = df_sym.index.values, autopct='%1.2f%%', figsize = (15,7.5))
# Out:
#              Disaster
# Fire            17809
# Other            2196
# Landslide         711
# Thunderbolt       554
# Flood             332
# Earthquake         82
# ['Fire', 'Other', 'Landslide', 'Thunderbolt', 'Flood', 'Earthquake']
# Categories (6, object): ['Earthquake', 'Fire', 'Flood', 'Landslide', 'Other', 'Thunderbolt']
# array([<Axes: ylabel='Disaster'>], dtype=object)

# %%
# Disaster occurence count by Province
df_sym = pd.DataFrame(disaster_data['province'].value_counts())
print(df_sym)

print(df_sym.index.values)
df_sym.plot.pie(subplots=True,labels = df_sym.index.values, autopct='%1.2f%%', figsize = (15,7.5))
# Out:
#                province
# Koshi              6568
# Madhesh            5445
# Lumbini            3445
# Bagmati            3343
# Gandaki            1170
# Sudurpashchim      1123
# Karnali             590
# ['Koshi', 'Madhesh', 'Lumbini', 'Bagmati', 'Gandaki', 'Sudurpashchim', 'Karnali']
# Categories (7, object): ['Bagmati', 'Gandaki', 'Karnali', 'Koshi', 'Lumbini', 'Madhesh',
#                          'Sudurpashchim']
# array([<Axes: ylabel='province'>], dtype=object)

# %%
def dist_box(data):
 # function plots a combined graph for univariate analysis of continous variable
 #to check spread, central tendency , dispersion and outliers
    Name=data.name.upper()
    fig,(ax_box,ax_dis)  = plt.subplots(2,1,gridspec_kw = {"height_ratios": (.25, .75)},figsize=(8, 5))
    print(fig,(ax_box,ax_dis))
    mean=data.mean()
    median=data.median()
    mode=data.mode().tolist()[0]

    fig.suptitle(f"SPREAD OF DATA FOR "+ Name  , fontsize=18, fontweight='bold')
    sns.boxplot(x=data,showmeans=True, orient='h',color="violet",ax=ax_box)
    ax_box.set(xlabel='')
    sns.distplot(data,kde=False,color='blue',ax=ax_dis)

    ax_dis.axvline(mean, color='r', linestyle='--',linewidth=2)
    ax_dis.axvline(median, color='g', linestyle='-',linewidth=2)
    ax_dis.axvline(mode, color='y', linestyle='-',linewidth=2)
    plt.legend({'Mean':mean,'Median':median,'Mode':mode})

# %%
#select all quantitative columns for checking the spread
list_col=  disaster_data.select_dtypes([np.number]).columns
for i in range(len(list_col)):
    dist_box(disaster_data[list_col[i]])

    # print(disaster_data[list_col[i]],'\n\n')
# Out:
# Figure(800x500) (<Axes: >, <Axes: >)
# Figure(800x500) (<Axes: >, <Axes: >)
# Figure(800x500) (<Axes: >, <Axes: >)
# Figure(800x500) (<Axes: >, <Axes: >)
# Figure(800x500) (<Axes: >, <Axes: >)
# Figure(800x500) (<Axes: >, <Axes: >)

# %%
# Choose the columns you want to display and sort by
sort_column = 'Total Death'  # Replace with the column name for sorting
display_columns = ['Disaster','incident_year', 'Total Death']  # Replace with the column names for display

# Sort the DataFrame by the chosen sort column in ascending order
sorted_data = disaster_data.sort_values(by=sort_column, ascending=False)

# Display the sorted DataFrame with the selected display columns
displayed_data = sorted_data[display_columns]

# Print the displayed data
print(displayed_data)
# Out:
#          Disaster  incident_year  Total Death
# 6357   Earthquake           2015         3570
# 6349   Earthquake           2015         1233
# 6355   Earthquake           2015         1112
# 6356   Earthquake           2015          681
# 6354   Earthquake           2015          680
# ...           ...            ...          ...
# 11514        Fire           2017            0
# 11513        Fire           2017            0
# 11512        Fire           2017            0
# 11510        Fire           2017            0
# 36346        Fire           2023            0
#
# [21684 rows x 3 columns]

# %% [markdown]
# **Observations**
# - We seem to observe outliers in every quantitative data; this is due to high magnitude disasters where a lives and property were destryoed in masses. Thus the outliers are not incorrect.
# - We will have to analyze data in such a way as to not exclude the outliers but work around them.
# - We can however, continue with our univariate analysis.

# %%
# Function to create barplots that indicate percentage for each category.
def bar_perc(plot, feature):
    total = len(feature) # length of the column
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        plot.annotate(percentage, (x, y), size = 12) # annotate the percentage

# %%
# Get all category datatype
list_col = disaster_data.select_dtypes(['category']).columns

# Calculate the number of rows and columns for subplots
num_cols = 2
num_rows = (len(list_col) + num_cols - 1) // num_cols

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))
axes = axes.flatten()  # Flatten the axes array for easy indexing

for i in range(len(list_col)):
    order = disaster_data[list_col[i]].value_counts(ascending=False).index
    ax = sns.countplot(x=list_col[i], data=disaster_data, order=order, ax=axes[i], palette='viridis')
    ax.set_title(list_col[i].upper())
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    bar_perc(ax, disaster_data[list_col[i]])

    # If we have an odd number of categorical columns, remove any unused subplots
    if i == len(list_col) - 1 and len(list_col) % 2 != 0:
        fig.delaxes(axes[i+1])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Set the size of the figure
plt.figure(figsize=(10, 6))  # Adjust the width and height values as needed

# Create a count plot for the 'incident_year' categories with adjusted bar spacing
ax = sns.countplot(data=disaster_data, x="incident_year", dodge=0.3)  # Adjust the dodge value as needed

# Calculate percentage of each category
total = len(disaster_data)
for p in ax.patches:
    height = p.get_height()
    percentage = (height / total) * 100
    ax.annotate(f'{percentage:.2f}%', (p.get_x() + p.get_width() / 2., height), ha='center')

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# **Observations**
#  - 82% of the total disaster incidents are fire, while earthquake accounts for only a mere 0.4%.
#  - Koshi province has recorded the highest number of disasters at 30%, followed by Madhesh province. Karnali province has recorded the least number of disaster incidents.
#  - The year 2019 has recorded the highest number of disaster incident while there in minimalistic record in 2015. This does not indicate that there was least disaster in 2015, but due to emergency crisis in Nepal during earthquake, records may have not been kept in timely order.
#  - On average, the number of incident records have been rising every year since 2011 AD.
#  - There has been large occurence of disaster incidents in Spring season followed by Summer, Winter and Autumn respectively.

# %% [markdown]
# ## Bivariate Analysis and Correlation

# %%
# Group and sum the data by 'Disaster' for different variables
grouped_data = disaster_data.groupby("Disaster").sum()
# List of variables to plot
variables_to_plot = ['Total Death', 'Estimated Loss', 'Affected Family', 'houses_fully_destroyed', 'houses_partially_destroyed' ]

# Loop through each variable and create a bar plot
for variable in variables_to_plot:
    plt.figure(figsize=(8, 4))
    sns.barplot(x=grouped_data.index, y=variable, data=grouped_data)
    plt.xlabel("Disaster")
    plt.ylabel(f"Total {variable.replace('_', ' ').title()}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# Let us check the sub-category of each categories for furthers analysis.
data = {}
list_col=  disaster_data.select_dtypes(['category']).columns
for i in range(len(list_col)):
  values = list(disaster_data[list_col[i]].value_counts())
  subcategory = list(disaster_data[list_col[i]].value_counts().index)
  # data['x'] = values
  data[list_col[i]] = [subcategory,values]

data
# Out:
# {'Disaster': [['Fire',
#    'Other',
#    'Landslide',
#    'Thunderbolt',
#    'Flood',
#    'Earthquake'],
#   [17809, 2196, 711, 554, 332, 82]],
#  'province': [['Koshi',
#    'Madhesh',
#    'Lumbini',
#    'Bagmati',
#    'Gandaki',
#    'Sudurpashchim',
#    'Karnali'],
#   [6568, 5445, 3445, 3343, 1170, 1123, 590]],
#  'season': [['Spring', 'Winter', 'Summer', 'Autumn'],
#   [7941, 5425, 4586, 3732]]}

# %%
disaster_data
# Out:
#           Disaster province   District  incident_year  season  Total Death  \
# 0             Fire  Bagmati  Kathmandu           2011  Spring            0
# 1            Other    Koshi    Sunsari           2011  Spring            0
# 2      Thunderbolt    Koshi   Dhankuta           2011  Spring            0
# 5             Fire  Madhesh  Mahottari           2011  Spring            0
# 6             Fire  Lumbini    Bardiya           2011  Spring            0
# ...            ...      ...        ...            ...     ...          ...
# 36339         Fire  Lumbini    Pyuthan           2023  Summer            0
# 36341        Other  Lumbini    Pyuthan           2023  Summer            0
# 36342         Fire  Bagmati  Kathmandu           2023  Summer            0
# 36345         Fire  Madhesh    Saptari           2023  Summer            0
# 36346         Fire    Koshi     Morang           2023  Summer            0
#
#        Estimated Loss  Affected Family  houses_fully_destroyed  \
# 0             50000.0                2                       0
# 1           7000000.0                0                       0
# 2            100000.0                0                       0
# 5            150000.0                1                       1
# 6            150000.0                0                       0
# ...               ...              ...                     ...
# 36339        400000.0                1                       0
# 36341        500000.0                2                       0
# 36342      24080687.0                1                       0
# 36345        300000.0                1                       0
# 36346         70000.0                1                       0
#
#        houses_partially_destroyed
# 0                               1
# 1                               0
# 2                               0
# 5                               0
# 6                               0
# ...                           ...
# 36339                           1
# 36341                           0
# 36342                           0
# 36345                           0
# 36346                           0
#
# [21684 rows x 10 columns]

# %%
disaster_data.corr()
# Out:
#                             incident_year  Total Death  Estimated Loss  \
# incident_year                    1.000000    -0.016105       -0.015136
# Total Death                     -0.016105     1.000000        0.010227
# Estimated Loss                  -0.015136     0.010227        1.000000
# Affected Family                 -0.015685     0.010172        0.477481
# houses_fully_destroyed          -0.024913     0.693448        0.012181
# houses_partially_destroyed      -0.029061     0.330806        0.091726
#
#                             Affected Family  houses_fully_destroyed  \
# incident_year                     -0.015685               -0.024913
# Total Death                        0.010172                0.693448
# Estimated Loss                     0.477481                0.012181
# Affected Family                    1.000000                0.022021
# houses_fully_destroyed             0.022021                1.000000
# houses_partially_destroyed         0.197270                0.538862
#
#                             houses_partially_destroyed
# incident_year                                -0.029061
# Total Death                                   0.330806
# Estimated Loss                                0.091726
# Affected Family                               0.197270
# houses_fully_destroyed                        0.538862
# houses_partially_destroyed                    1.000000

# %%
plt.figure(figsize=(15,5))
sns.heatmap(disaster_data.corr(),annot=True ,cmap="YlGn" )
plt.show()

# %% [markdown]
# **Observation**
#   - There correlation can be summarized as:
#       1. Marked degree of correlation between 'Total death' and 'houses fully destroyed'.
#       2. Moderate degree of correlation between 'houses fully 'and 'houses partially destroyed'.
#       3. Moderate degree of correlation between 'Affected family' and 'Estimated loss'.
#       4. Low degree of correlation between'Total death' and 'houses partially destroyed'.

# %%
disaster_data.describe()
# Out:
#        incident_year   Total Death  Estimated Loss  Affected Family  \
# count   21684.000000  21684.000000    2.168400e+04     21684.000000
# mean     2018.369996      0.453468    2.107875e+06         3.397344
# std         3.360262     27.938414    7.468852e+07       145.129257
# min      2011.000000      0.000000    0.000000e+00         0.000000
# 25%      2016.000000      0.000000    1.000000e+05         1.000000
# 50%      2019.000000      0.000000    2.500000e+05         1.000000
# 75%      2021.000000      0.000000    6.540000e+05         1.000000
# max      2023.000000   3570.000000    1.005285e+10     17376.000000
#
#        houses_fully_destroyed  houses_partially_destroyed
# count            21684.000000                21684.000000
# mean                37.075909                   15.486857
# std               1482.503752                  533.415950
# min                  0.000000                    0.000000
# 25%                  0.000000                    0.000000
# 50%                  0.000000                    0.000000
# 75%                  1.000000                    0.000000
# max              90594.000000                55427.000000

# %% [markdown]
# **There is significant skewness in data as seen from mean and median values, in order to make this pattern more interpretable we have to use log transform.**

# %%
# List of quantitative columns to transform
quantitative_columns = ['Total Death', 'Estimated Loss', 'Affected Family', 'houses_fully_destroyed','houses_partially_destroyed']

# Create new columns with the log-transformed values
for col in quantitative_columns:
    new_col_name = f'Log_{col}'
    disaster_data[new_col_name] = np.log1p(disaster_data[col])

disaster_data
# Out:
#           Disaster province   District  incident_year  season  Total Death  \
# 0             Fire  Bagmati  Kathmandu           2011  Spring            0
# 1            Other    Koshi    Sunsari           2011  Spring            0
# 2      Thunderbolt    Koshi   Dhankuta           2011  Spring            0
# 5             Fire  Madhesh  Mahottari           2011  Spring            0
# 6             Fire  Lumbini    Bardiya           2011  Spring            0
# ...            ...      ...        ...            ...     ...          ...
# 36339         Fire  Lumbini    Pyuthan           2023  Summer            0
# 36341        Other  Lumbini    Pyuthan           2023  Summer            0
# 36342         Fire  Bagmati  Kathmandu           2023  Summer            0
# 36345         Fire  Madhesh    Saptari           2023  Summer            0
# 36346         Fire    Koshi     Morang           2023  Summer            0
#
#        Estimated Loss  Affected Family  houses_fully_destroyed  \
# 0             50000.0                2                       0
# 1           7000000.0                0                       0
# 2            100000.0                0                       0
# 5            150000.0                1                       1
# 6            150000.0                0                       0
# ...               ...              ...                     ...
# 36339        400000.0                1                       0
# 36341        500000.0                2                       0
# 36342      24080687.0                1                       0
# 36345        300000.0                1                       0
# 36346         70000.0                1                       0
#
#        houses_partially_destroyed  Log_Total Death  Log_Estimated Loss  \
# 0                               1              0.0           10.819798
# 1                               0              0.0           15.761421
# 2                               0              0.0           11.512935
# 5                               0              0.0           11.918397
# 6                               0              0.0           11.918397
# ...                           ...              ...                 ...
# 36339                           1              0.0           12.899222
# 36341                           0              0.0           13.122365
# 36342                           0              0.0           16.996921
# 36345                           0              0.0           12.611541
# 36346                           0              0.0           11.156265
#
#        Log_Affected Family  Log_houses_fully_destroyed  \
# 0                 1.098612                    0.000000
# 1                 0.000000                    0.000000
# 2                 0.000000                    0.000000
# 5                 0.693147                    0.693147
# 6                 0.000000                    0.000000
# ...                    ...                         ...
# 36339             0.693147                    0.000000
# 36341             1.098612                    0.000000
# 36342             0.693147                    0.000000
# 36345             0.693147                    0.000000
# 36346             0.693147                    0.000000
#
#        Log_houses_partially_destroyed
# 0                            0.693147
# 1                            0.000000
# 2                            0.000000
# 5                            0.000000
# 6                            0.000000
# ...                               ...
# 36339                        0.693147
# 36341                        0.000000
# 36342                        0.000000
# 36345                        0.000000
# 36346                        0.000000
#
# [21684 rows x 15 columns]

# %%
plt.figure(figsize=(5,5))
columns = ['incident_year','Log_Total Death', 'Log_Estimated Loss', 'Log_Affected Family', 'Log_houses_fully_destroyed','Log_houses_partially_destroyed']
sns.pairplot(data=disaster_data[columns] , corner=True)
plt.show()

# %% [markdown]
# **Observation**
#  - The log transform pair plot shows some pattern in most parameters
#  - This is an indication that there might be  an exponential relationship between the parameters but can't be said with certainity.
#  - So, let us check the correlation between the parameters in 'Log Transform'.

# %%
selected_columns = ['incident_year','Log_Total Death', 'Log_Estimated Loss', 'Log_Affected Family', 'Log_houses_fully_destroyed','Log_houses_partially_destroyed']

# Create a DataFrame containing only the selected columns
selected_data = disaster_data[selected_columns]

# Generate the heatmap of the correlation matrix
plt.figure(figsize=(15, 5))
sns.heatmap(selected_data.corr(), annot=True, cmap="YlGn")
plt.title("Correlation Heatmap of Selected Variables")
plt.show()

# %% [markdown]
# **Observation**
# - There seems to be no good correlation between parameters in log transform so we try by adopting 'standarization' technique in regression.

# %%
disaster_data = disaster_data.drop(['Log_Total Death', 'Log_Estimated Loss', 'Log_Affected Family', 'Log_houses_fully_destroyed','Log_houses_partially_destroyed'], axis=1)
disaster_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21684 entries, 0 to 36346
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Disaster                    21684 non-null  category
#  1   province                    21684 non-null  category
#  2   District                    21684 non-null  object
#  3   incident_year               21684 non-null  int64
#  4   season                      21684 non-null  category
#  5   Total Death                 21684 non-null  int64
#  6   Estimated Loss              21684 non-null  float64
#  7   Affected Family             21684 non-null  int64
#  8   houses_fully_destroyed      21684 non-null  int64
#  9   houses_partially_destroyed  21684 non-null  int64
# dtypes: category(3), float64(1), int64(5), object(1)
# memory usage: 1.4+ MB

# %%
disaster_data.describe(include = "category")
# Out:
#        Disaster province  season
# count     21684    21684   21684
# unique        6        7       4
# top        Fire    Koshi  Spring
# freq      17809     6568    7941

# %%
plt.figure(figsize=(13,5))
sns.set(style="whitegrid")
ax=sns.countplot(x='province',hue='season',data=disaster_data,palette='rainbow')
bar_perc(ax,disaster_data['province'])
plt.xticks(rotation=45)
ax.set(title="Province vs Season")
# Out:
# [Text(0.5, 1.0, 'Province vs Season')]

# %%
# Filter the data for seasonal disasters
selected_disasters = ['Fire', 'Landslide', 'Thunderbolt', 'Flood']
filtered_data = disaster_data[disaster_data['Disaster'].isin(selected_disasters)]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(18, 10))

for i, disaster in enumerate(selected_disasters):
    row, col = divmod(i, 2)
    ax = axes[row, col]
    current_disaster_data = filtered_data[filtered_data['Disaster'] == disaster]
    sns.countplot(data=current_disaster_data, x='season', ax=ax, palette='rainbow')

    for p in ax.patches:
        ax.annotate(format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                    textcoords='offset points')

        ax.set_title(f"{disaster} per Seasons")
    ax.set_xlabel("Season")
    ax.set_ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# Let us take a closer look at seasonal relation with disaster like landslide, fire, thunderbolt and flood.

# %% [markdown]
# **Observation**
# - Disasters in Spring season have occured most in all provinces.
# - Bagmati province, which houses the capital of Nepal, has recorded disasters in Spring season more than any other season followed by Winter, Summer and Autumn.
# - It is evicent that Flood and Landslide has mostly occured in Summer season since summer is accomanied by most parts of the monsoon in Nepal.
# - Interestingly Fire and thunderbolt are mostly seen in Spring seasons. This season records fair amount of winds and storm in Nepal.

# %%
# Filter the data for Major disasters only
selected_disasters = ['Thunderbolt','Fire', 'Landslide', 'Flood']
filtered_data = disaster_data[disaster_data['Disaster'].isin(selected_disasters)]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(18, 10))

for i, disaster in enumerate(selected_disasters):
    row, col = divmod(i, 2)
    ax = axes[row, col]
    current_disaster_data = filtered_data[filtered_data['Disaster'] == disaster]
    sns.countplot(data=current_disaster_data, x='province', ax=ax, palette='rainbow')

    for p in ax.patches:
        ax.annotate(format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                    textcoords='offset points')

        ax.set_title(f"{disaster} per Province")
    ax.set_xlabel("Province")
    ax.set_ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**
# - Koshi province has recorded highest number of every seasonal type of disastrous events.
# - It should be noted that since Madhess province lies in Terai only, only two landslides can be seen and that might possibly be mud-slides.
# - Flood occures mostly in Bagmati, Koshi, Lumbini and Madhesh province all of which have significant number of seasonal rivers originating from mountains contrary to perenial rivers originating from glaciers.

# %%
selected_disasters = ['Landslide']
filtered_data = disaster_data[disaster_data['Disaster'].isin(selected_disasters)]

# Create a countplot with stretched bar width
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=filtered_data, x='incident_year', hue='Disaster', palette='Set2', dodge=False)
plt.title('Number of Floods Every Year')
plt.xlabel('Incident Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Disaster', loc='upper right')

# Add sum values at the top of each bar
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=10, color='black')

# Add a vertical line and label
incident_year_to_mark = 2015
ax.axvline(x=incident_year_to_mark - 2011, color='red', linestyle='--', label='Marked Year')
ax.annotate('7.8 Magnitude Earthquake', xy=(incident_year_to_mark - 2011, 0.95), xytext=(10, 10),
            textcoords='offset points', color='red', fontsize=10)

plt.tight_layout()
plt.show()

# %%
selected_disasters = ['Flood']
filtered_data = disaster_data[disaster_data['Disaster'].isin(selected_disasters)]

# Create a countplot with stretched bar width
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=filtered_data, x='incident_year', hue='Disaster', palette='Set2', dodge=False)
plt.title('Number of Landslide Every Year')
plt.xlabel('Incident Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Disaster', loc='upper right')

# Add sum values at the top of each bar
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=10, color='black')

# Add a vertical line and label
incident_year_to_mark = 2015
ax.axvline(x=incident_year_to_mark - 2011, color='red', linestyle='--', label='Marked Year')
ax.annotate('7.8 Magnitude Earthquake', xy=(incident_year_to_mark - 2011, 0.95), xytext=(10, 10),
            textcoords='offset points', color='red', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**
# - Looking at flood and landsilde data after the 2015 earthquake, it can be seen that significant number of such events have escalated since.
# - The data is more prominent in landslide case indicating the earthquaked has indeed affected the soil and rocks of mountains and hills causing huge number of landslides in the succeeding year.

# %%
# Calculate the cumulative sum of Estimated Loss per year
cumulative_loss_per_year = disaster_data.groupby("incident_year")["Estimated Loss"].sum().cumsum()

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# First subplot: Estimated Loss by Incident Year
sns.lineplot(x="incident_year", y="Estimated Loss", data=disaster_data, estimator='sum', ax=axes[0])
axes[0].set_title('Estimated Loss by Incident Year')
axes[0].set_xlabel("Incident Year")
axes[0].set_ylabel("Estimated Loss")
axes[0].set_xticks(disaster_data["incident_year"].unique())
axes[0].tick_params(axis='x', rotation=45)

# Second subplot: Cumulative Sum of Estimated Loss per Year
sns.lineplot(x=cumulative_loss_per_year.index, y=cumulative_loss_per_year.values, ax=axes[1])
axes[1].set_title('Cumulative Sum of Estimated Loss')
axes[1].set_xlabel("Incident Year")
axes[1].set_ylabel("Estimated Loss")
axes[1].set_xticks(cumulative_loss_per_year.index)
axes[1].tick_params(axis='x', rotation=45)

# Fill the area under the line
axes[1].fill_between(cumulative_loss_per_year.index, cumulative_loss_per_year.values, color='firebrick', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
disaster_data.groupby("Disaster")["Estimated Loss"].sum()
# Out:
# Disaster
# Earthquake     6.480000e+06
# Fire           2.553198e+10
# Flood          1.709396e+10
# Landslide      1.884919e+09
# Other          1.093705e+09
# Thunderbolt    9.612176e+07
# Name: Estimated Loss, dtype: float64

# %%
disaster_data.groupby("incident_year")["Estimated Loss"].sum()
# Out:
# incident_year
# 2011    9.942077e+08
# 2012    1.291896e+09
# 2013    2.056863e+09
# 2014    1.681504e+10
# 2015    9.445895e+08
# 2016    2.812379e+09
# 2017    2.496785e+09
# 2018    4.341892e+09
# 2019    4.709510e+09
# 2020    1.761221e+09
# 2021    2.542812e+09
# 2022    2.803543e+09
# 2023    2.136427e+09
# Name: Estimated Loss, dtype: float64

# %% [markdown]
# **Observation**
# - The estimated loss due to disasters in increasing ever since 2011 AD.
# - The yearly graph shows the disastrous losses in 2014 AD due to flood in the Terai regions.
# - The losses in 2015 is less despite the earthquake in that year, the reason might be that the calculation of actual loss took more time and was recorded in succeding years.

# %% [markdown]
# ## Multivariate Analysis

# %%
cumulative_loss_per_year = disaster_data.groupby(["incident_year", "Disaster"])["Estimated Loss"].sum()
cumulative_loss_per_year = cumulative_loss_per_year.reset_index()

# Calculate cumulative sum by adding the loss of the previous year to the current year
cumulative_loss_per_year["Cumulative Loss"] = cumulative_loss_per_year.groupby("Disaster")["Estimated Loss"].cumsum()

# Create the cumulative graph
plt.figure(figsize=(10, 6))

# Stacked fill areas under each line
for disaster in cumulative_loss_per_year["Disaster"].unique():
    current_data = cumulative_loss_per_year[cumulative_loss_per_year["Disaster"] == disaster]
    plt.fill_between(current_data["incident_year"], 0, current_data["Cumulative Loss"],
                     alpha=0.2, label=disaster)
# Plot the lines
sns.lineplot(data=cumulative_loss_per_year, x="incident_year", y="Cumulative Loss", hue="Disaster")
plt.title('Cumulative Sum of Estimated Loss')
plt.xlabel("Year")
plt.ylabel("Cumulative Estimated Loss")
plt.legend(loc='lower right')

# Create a custom legend with max values
custom_legend = []
for disaster in cumulative_loss_per_year["Disaster"].unique():
    max_value = cumulative_loss_per_year[cumulative_loss_per_year["Disaster"] == disaster]["Cumulative Loss"].max()
    custom_legend.append(f'{disaster} (Max: {max_value:.2f})')

plt.legend(custom_legend, loc='upper left')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
cumulative_deaths_per_year = disaster_data.groupby(["incident_year", "Disaster"])["Total Death"].sum()
cumulative_deaths_per_year = cumulative_deaths_per_year.reset_index()

# Calculate cumulative sum by adding the loss of the previous year to the current year
cumulative_deaths_per_year["Cumulative Deaths"] = cumulative_deaths_per_year.groupby("Disaster")["Total Death"].cumsum()

# Create the cumulative graph
plt.figure(figsize=(10, 6))

# Stacked fill areas under each line
for disaster in cumulative_deaths_per_year["Disaster"].unique():
    current_data = cumulative_deaths_per_year[cumulative_deaths_per_year["Disaster"] == disaster]
    plt.fill_between(current_data["incident_year"], 0, current_data["Cumulative Deaths"],
                     alpha=0.2, label=disaster)
# Plot the lines
sns.lineplot(data=cumulative_deaths_per_year, x="incident_year", y="Cumulative Deaths", hue="Disaster")
plt.title('Cumulative Sum of Deaths')
plt.xlabel("Year")
plt.ylabel("Cumulative Deaths")
plt.legend(loc='lower right')

# Create a custom legend with max values
custom_legend = []
for disaster in cumulative_deaths_per_year["Disaster"].unique():
    max_value = cumulative_deaths_per_year[cumulative_deaths_per_year["Disaster"] == disaster]["Cumulative Deaths"].max()
    custom_legend.append(f'{disaster} (Max: {max_value:.2f})')

plt.legend(custom_legend, loc='upper left')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
cumulative_affected_family_per_year = disaster_data.groupby(["incident_year", "Disaster"])["Affected Family"].sum()
cumulative_affected_family_per_year = cumulative_affected_family_per_year.reset_index()

# Calculate cumulative sum by adding the loss of the previous year to the current year
cumulative_affected_family_per_year["Cumulative Affected"] = cumulative_affected_family_per_year.groupby("Disaster")["Affected Family"].cumsum()

# Create the cumulative graph
plt.figure(figsize=(10, 6))

# Stacked fill areas under each line
for disaster in cumulative_affected_family_per_year["Disaster"].unique():
    current_data = cumulative_affected_family_per_year[cumulative_affected_family_per_year["Disaster"] == disaster]
    plt.fill_between(current_data["incident_year"], 0, current_data["Cumulative Affected"],
                     alpha=0.2, label=disaster)
# Plot the lines
sns.lineplot(data=cumulative_affected_family_per_year, x="incident_year", y="Cumulative Affected", hue="Disaster")
plt.title('Cumulative Sum of Affected Families')
plt.xlabel("Year")
plt.ylabel("Cumulative Affected Family")
plt.legend(loc='lower right')

# Create a custom legend with max values
custom_legend = []
for disaster in cumulative_affected_family_per_year["Disaster"].unique():
    max_value = cumulative_affected_family_per_year[cumulative_affected_family_per_year["Disaster"] == disaster]["Cumulative Affected"].max()
    custom_legend.append(f'{disaster} (Max: {max_value:.2f})')

plt.legend(custom_legend, loc='upper left')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations**
#  - It can be seen that till date Fire has caused the most losses in economic terms followed by flood and landslide. Interestingly, Earthquake ranks at four.
#  - Earthquake of 2015 was the cause of the highest number of deaths recorded till date.
#  - The number of affected families are caused by flood, fire, earthquake and landslide in descending order.
#  - The slope of fire disaster in affected family parameters indicate that it has been rising at an alarming rate.

# %% [markdown]
# ****CONCLUSIONS based on EDA****
#
#
# 1.   The 2015 Earthquake was the one single event causing the highest number of fatalities and it surpasses the deaths of all the other disasters combined.
# 2.   There has been significant rise in number of landslides and floods since the earthquake of 2015.
# 3.  Fires cause the most economic losses in Nepal.
# 4. Floods and Fires affect the families of Nepal more than any other disasters.
# 5. The seasons of Nepal do have an impact in the occurence of disasters like flood, landslide, fires(also Forest fires) and thunderbolt.

# %% [markdown]
# ## Disaster Deaths prediction using Linear Regression

# %%
auto=disaster_data[['Total Death', 'Estimated Loss', 'Affected Family', 'houses_fully_destroyed', 'houses_partially_destroyed','season']]
auto.head(5)
# Out:
#    Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# 0            0         50000.0                2                       0
# 1            0       7000000.0                0                       0
# 2            0        100000.0                0                       0
# 5            0        150000.0                1                       1
# 6            0        150000.0                0                       0
#
#    houses_partially_destroyed  season
# 0                           1  Spring
# 1                           0  Spring
# 2                           0  Spring
# 5                           0  Spring
# 6                           0  Spring

# %% [markdown]
# **Dimension Reduction**

# %%
season_type = pd.get_dummies(auto['season'], drop_first = True)
season_type
# Out:
#        Spring  Summer  Winter
# 0           1       0       0
# 1           1       0       0
# 2           1       0       0
# 5           1       0       0
# 6           1       0       0
# ...       ...     ...     ...
# 36339       0       1       0
# 36341       0       1       0
# 36342       0       1       0
# 36345       0       1       0
# 36346       0       1       0
#
# [21684 rows x 3 columns]

# %%
auto = pd.concat([auto, season_type], axis = 1)
auto
# Out:
#        Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# 0                0         50000.0                2                       0
# 1                0       7000000.0                0                       0
# 2                0        100000.0                0                       0
# 5                0        150000.0                1                       1
# 6                0        150000.0                0                       0
# ...            ...             ...              ...                     ...
# 36339            0        400000.0                1                       0
# 36341            0        500000.0                2                       0
# 36342            0      24080687.0                1                       0
# 36345            0        300000.0                1                       0
# 36346            0         70000.0                1                       0
#
#        houses_partially_destroyed  season  Spring  Summer  Winter
# 0                               1  Spring       1       0       0
# 1                               0  Spring       1       0       0
# 2                               0  Spring       1       0       0
# 5                               0  Spring       1       0       0
# 6                               0  Spring       1       0       0
# ...                           ...     ...     ...     ...     ...
# 36339                           1  Summer       0       1       0
# 36341                           0  Summer       0       1       0
# 36342                           0  Summer       0       1       0
# 36345                           0  Summer       0       1       0
# 36346                           0  Summer       0       1       0
#
# [21684 rows x 9 columns]

# %%
auto.drop(['season'], axis = 1, inplace = True)
auto.head(5)
# Out:
#    Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# 0            0         50000.0                2                       0
# 1            0       7000000.0                0                       0
# 2            0        100000.0                0                       0
# 5            0        150000.0                1                       1
# 6            0        150000.0                0                       0
#
#    houses_partially_destroyed  Spring  Summer  Winter
# 0                           1       1       0       0
# 1                           0       1       0       0
# 2                           0       1       0       0
# 5                           0       1       0       0
# 6                           0       1       0       0

# %% [markdown]
# **Start Machine Learning**

# %%
from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
df_train, df_test = train_test_split(auto, train_size = 0.7, test_size = 0.3, random_state = 1)
print(df_train)
print(df_test)
# Out:
#        Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# 21006            0        547000.0                1                       1
# 20040            0         65000.0                1                       0
# 26620            0       1400000.0                1                       0
# 27918            0         50000.0                1                       0
# 7383             1             0.0                1                       0
# ...            ...             ...              ...                     ...
# 16893            0        700000.0                1                       0
# 28567            0        200000.0                1                       1
# 7708             0             0.0                0                       0
# 19441            0        200000.0                1                       0
# 503              0         50000.0                0                       1
#
#        houses_partially_destroyed  Spring  Summer  Winter
# 21006                           0       1       0       0
# 20040                           1       0       0       1
# 26620                           1       0       1       0
# 27918                           0       0       0       1
# 7383                            0       1       0       0
# ...                           ...     ...     ...     ...
# 16893                           1       1       0       0
# 28567                           0       0       0       1
# 7708                            0       1       0       0
# 19441                           0       0       0       0
# 503                             0       0       1       0
#
# [15178 rows x 8 columns]
#        Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# 32651            0         12000.0                1                       0
# 12568            0       1004500.0                3                       0
# 1702             0       2900000.0                1                       1
# 8700             0        670000.0                1                       1
# 31987            0        200000.0                1                       1
# ...            ...             ...              ...                     ...
# 13030            0        600000.0                3                       3
# 36100            0         70000.0                2                       0
# 25258            0        100000.0                1                       0
# 9048             0       2150000.0                1                       1
# 23976            0        300000.0                2                       0
#
#        houses_partially_destroyed  Spring  Summer  Winter
# 32651                           0       0       0       1
# 12568                           0       1       0       0
# 1702                            0       1       0       0
# 8700                            0       0       1       0
# 31987                           0       0       0       1
# ...                           ...     ...     ...     ...
# 13030                           0       1       0       0
# 36100                           0       0       1       0
# 25258                           0       1       0       0
# 9048                            0       0       0       0
# 23976                           2       0       0       1
#
# [6506 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler
# Out:
# MinMaxScaler()

# %%
df_train.describe()
# Out:
#         Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# count  15178.000000    1.517800e+04     15178.000000            15178.000000
# mean       0.390499    1.740389e+06         3.878640               29.677889
# std       29.891103    3.525038e+07       170.533405             1285.435808
# min        0.000000    0.000000e+00         0.000000                0.000000
# 25%        0.000000    1.000000e+05         1.000000                0.000000
# 50%        0.000000    2.500000e+05         1.000000                0.000000
# 75%        0.000000    6.500000e+05         1.000000                1.000000
# max     3570.000000    3.775406e+09     17376.000000            90594.000000
#
#        houses_partially_destroyed        Spring        Summer        Winter
# count                15178.000000  15178.000000  15178.000000  15178.000000
# mean                    11.637568      0.364343      0.212215      0.250955
# std                    326.561574      0.481261      0.408890      0.433577
# min                      0.000000      0.000000      0.000000      0.000000
# 25%                      0.000000      0.000000      0.000000      0.000000
# 50%                      0.000000      0.000000      0.000000      0.000000
# 75%                      0.000000      1.000000      0.000000      1.000000
# max                  17560.000000      1.000000      1.000000      1.000000

# %%
# Apply scaler() to all the columns except the 'dummy' variables
num_vars = ['Total Death', 'Estimated Loss', 'Affected Family', 'houses_fully_destroyed', 'houses_partially_destroyed']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.describe()
# Out:
#         Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# count  15178.000000    15178.000000     15178.000000            15178.000000
# mean       0.000109        0.000461         0.000223                0.000328
# std        0.008373        0.009337         0.009814                0.014189
# min        0.000000        0.000000         0.000000                0.000000
# 25%        0.000000        0.000026         0.000058                0.000000
# 50%        0.000000        0.000066         0.000058                0.000000
# 75%        0.000000        0.000172         0.000058                0.000011
# max        1.000000        1.000000         1.000000                1.000000
#
#        houses_partially_destroyed        Spring        Summer        Winter
# count                15178.000000  15178.000000  15178.000000  15178.000000
# mean                     0.000663      0.364343      0.212215      0.250955
# std                      0.018597      0.481261      0.408890      0.433577
# min                      0.000000      0.000000      0.000000      0.000000
# 25%                      0.000000      0.000000      0.000000      0.000000
# 50%                      0.000000      0.000000      0.000000      0.000000
# 75%                      0.000000      1.000000      0.000000      1.000000
# max                      1.000000      1.000000      1.000000      1.000000

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True,)
plt.show()

# %% [markdown]
# There is no much correlation between the parameters.

# %%
y_train = df_train.pop('Estimated Loss')
X_train = df_train

# %%
y_train
# Out:
# 21006    0.000145
# 20040    0.000017
# 26620    0.000371
# 27918    0.000013
# 7383     0.000000
#            ...
# 16893    0.000185
# 28567    0.000053
# 7708     0.000000
# 19441    0.000053
# 503      0.000013
# Name: Estimated Loss, Length: 15178, dtype: float64

# %%
X_train
# Out:
#        Total Death  Affected Family  houses_fully_destroyed  \
# 21006      0.00000         0.000058                0.000011
# 20040      0.00000         0.000058                0.000000
# 26620      0.00000         0.000058                0.000000
# 27918      0.00000         0.000058                0.000000
# 7383       0.00028         0.000058                0.000000
# ...            ...              ...                     ...
# 16893      0.00000         0.000058                0.000000
# 28567      0.00000         0.000058                0.000011
# 7708       0.00000         0.000000                0.000000
# 19441      0.00000         0.000058                0.000000
# 503        0.00000         0.000000                0.000011
#
#        houses_partially_destroyed  Spring  Summer  Winter
# 21006                    0.000000       1       0       0
# 20040                    0.000057       0       0       1
# 26620                    0.000057       0       1       0
# 27918                    0.000000       0       0       1
# 7383                     0.000000       1       0       0
# ...                           ...     ...     ...     ...
# 16893                    0.000057       1       0       0
# 28567                    0.000000       0       0       1
# 7708                     0.000000       1       0       0
# 19441                    0.000000       0       0       0
# 503                      0.000000       0       1       0
#
# [15178 rows x 7 columns]

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 10
lm = LinearRegression()
# lm.fit(X_train, y_train)

#rfe = RFE(lm, 10)
rfe = RFE(lm, n_features_to_select=10)
#running RFE
rfe = rfe.fit(X_train, y_train)

# %%
X_train.columns
# Out:
# Index(['Total Death', 'Affected Family', 'houses_fully_destroyed',
#        'houses_partially_destroyed', 'Spring', 'Summer', 'Winter'],
#       dtype='object')

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('Total Death', True, 1),
#  ('Affected Family', True, 1),
#  ('houses_fully_destroyed', True, 1),
#  ('houses_partially_destroyed', True, 1),
#  ('Spring', True, 1),
#  ('Summer', True, 1),
#  ('Winter', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['Total Death', 'Affected Family', 'houses_fully_destroyed',
#        'houses_partially_destroyed', 'Spring', 'Summer', 'Winter'],
#       dtype='object')

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
X_train_rfe
# Out:
#        Total Death  Affected Family  houses_fully_destroyed  \
# 21006      0.00000         0.000058                0.000011
# 20040      0.00000         0.000058                0.000000
# 26620      0.00000         0.000058                0.000000
# 27918      0.00000         0.000058                0.000000
# 7383       0.00028         0.000058                0.000000
# ...            ...              ...                     ...
# 16893      0.00000         0.000058                0.000000
# 28567      0.00000         0.000058                0.000011
# 7708       0.00000         0.000000                0.000000
# 19441      0.00000         0.000058                0.000000
# 503        0.00000         0.000000                0.000011
#
#        houses_partially_destroyed  Spring  Summer  Winter
# 21006                    0.000000       1       0       0
# 20040                    0.000057       0       0       1
# 26620                    0.000057       0       1       0
# 27918                    0.000000       0       0       1
# 7383                     0.000000       1       0       0
# ...                           ...     ...     ...     ...
# 16893                    0.000057       1       0       0
# 28567                    0.000000       0       0       1
# 7708                     0.000000       1       0       0
# 19441                    0.000000       0       0       0
# 503                      0.000000       0       1       0
#
# [15178 rows x 7 columns]

# %%
# Adding a constant variable
import statsmodels.api as sm
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
X_train_rfe
# Out:
#        const  Total Death  Affected Family  houses_fully_destroyed  \
# 21006    1.0      0.00000         0.000058                0.000011
# 20040    1.0      0.00000         0.000058                0.000000
# 26620    1.0      0.00000         0.000058                0.000000
# 27918    1.0      0.00000         0.000058                0.000000
# 7383     1.0      0.00028         0.000058                0.000000
# ...      ...          ...              ...                     ...
# 16893    1.0      0.00000         0.000058                0.000000
# 28567    1.0      0.00000         0.000058                0.000011
# 7708     1.0      0.00000         0.000000                0.000000
# 19441    1.0      0.00000         0.000058                0.000000
# 503      1.0      0.00000         0.000000                0.000011
#
#        houses_partially_destroyed  Spring  Summer  Winter
# 21006                    0.000000       1       0       0
# 20040                    0.000057       0       0       1
# 26620                    0.000057       0       1       0
# 27918                    0.000000       0       0       1
# 7383                     0.000000       1       0       0
# ...                           ...     ...     ...     ...
# 16893                    0.000057       1       0       0
# 28567                    0.000000       0       0       1
# 7708                     0.000000       1       0       0
# 19441                    0.000000       0       0       0
# 503                      0.000000       0       1       0
#
# [15178 rows x 8 columns]

# %% [markdown]
# **Ordinary Least Squares regression (OLS)** is a common technique for estimating coefficients of linear regression equations which describe the relationship between one or more independent quantitative variables and a dependent variable (simple or multiple linear regression).

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()  # Running the linear model

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Estimated Loss   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     3969.
# Date:                Tue, 19 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:46:27   Log-Likelihood:                 57301.
# No. Observations:               15178   AIC:                        -1.146e+05
# Df Residuals:                   15170   BIC:                        -1.145e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.0003      0.000      2.785      0.005    8.94e-05       0.001
# Total Death                    0.0146      0.009      1.630      0.103      -0.003       0.032
# Affected Family                0.7571      0.005    144.873      0.000       0.747       0.767
# houses_fully_destroyed        -0.0149      0.006     -2.318      0.020      -0.027      -0.002
# houses_partially_destroyed     0.0114      0.004      3.123      0.002       0.004       0.019
# Spring                       -6.6e-05      0.000     -0.501      0.616      -0.000       0.000
# Summer                         0.0001      0.000      0.813      0.416      -0.000       0.000
# Winter                     -6.178e-05      0.000     -0.438      0.661      -0.000       0.000
# ==============================================================================
# Omnibus:                    28995.658   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3647981423.822
# Skew:                          13.196   Prob(JB):                         0.00
# Kurtosis:                    2404.588   Cond. No.                         269.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Dropping Winter as p-value is high.
X_train_new1 = X_train_rfe.drop(["Spring"], axis = 1)
X_train_new1

# Adding a constant variable
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_new1)

lm = sm.OLS(y_train,X_train_new1).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Estimated Loss   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     4631.
# Date:                Tue, 19 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:46:27   Log-Likelihood:                 57301.
# No. Observations:               15178   AIC:                        -1.146e+05
# Df Residuals:                   15171   BIC:                        -1.145e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.0003   6.15e-05      4.181      0.000       0.000       0.000
# Total Death                    0.0146      0.009      1.628      0.104      -0.003       0.032
# Affected Family                0.7571      0.005    144.892      0.000       0.747       0.767
# houses_fully_destroyed        -0.0149      0.006     -2.317      0.021      -0.027      -0.002
# houses_partially_destroyed     0.0114      0.004      3.113      0.002       0.004       0.019
# Summer                         0.0002      0.000      1.415      0.157    -6.3e-05       0.000
# Winter                     -1.702e-05      0.000     -0.156      0.876      -0.000       0.000
# ==============================================================================
# Omnibus:                    28995.890   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3647770193.564
# Skew:                          13.196   Prob(JB):                         0.00
# Kurtosis:                    2404.518   Cond. No.                         255.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Dropping Spring as p-value is high.
X_train_new2 = X_train_new1.drop(["Winter"], axis = 1)

# Adding a constant variable
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_new2)

lm = sm.OLS(y_train,X_train_new2).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Estimated Loss   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     5558.
# Date:                Tue, 19 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:46:27   Log-Likelihood:                 57301.
# No. Observations:               15178   AIC:                        -1.146e+05
# Df Residuals:                   15172   BIC:                        -1.145e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.0003   5.08e-05      4.959      0.000       0.000       0.000
# Total Death                    0.0146      0.009      1.628      0.103      -0.003       0.032
# Affected Family                0.7571      0.005    144.899      0.000       0.747       0.767
# houses_fully_destroyed        -0.0149      0.006     -2.317      0.021      -0.027      -0.002
# houses_partially_destroyed     0.0114      0.004      3.116      0.002       0.004       0.019
# Summer                         0.0002      0.000      1.533      0.125   -4.71e-05       0.000
# ==============================================================================
# Omnibus:                    28995.908   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3647784661.247
# Skew:                          13.196   Prob(JB):                         0.00
# Kurtosis:                    2404.523   Cond. No.                         247.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Dropping Summer as p-value is high.
X_train_new3 = X_train_new2.drop(["houses_partially_destroyed"], axis = 1)

# Adding a constant variable
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_new3)

lm = sm.OLS(y_train,X_train_new3).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Estimated Loss   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     6941.
# Date:                Tue, 19 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:46:27   Log-Likelihood:                 57296.
# No. Observations:               15178   AIC:                        -1.146e+05
# Df Residuals:                   15173   BIC:                        -1.145e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.0003   5.08e-05      5.031      0.000       0.000       0.000
# Total Death                0.0016      0.008      0.207      0.836      -0.014       0.017
# Affected Family            0.7648      0.005    166.438      0.000       0.756       0.774
# houses_fully_destroyed    -0.0012      0.005     -0.248      0.804      -0.010       0.008
# Summer                     0.0002      0.000      1.493      0.135   -5.14e-05       0.000
# ==============================================================================
# Omnibus:                    29011.299   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3644784518.128
# Skew:                          13.214   Prob(JB):                         0.00
# Kurtosis:                    2403.535   Cond. No.                         199.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Dropping Total Death as p-value is high.
X_train_new4 = X_train_new3.drop(["houses_fully_destroyed"], axis = 1)

# Adding a constant variable
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_new4)

lm = sm.OLS(y_train,X_train_new4).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Estimated Loss   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     9255.
# Date:                Tue, 19 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:46:27   Log-Likelihood:                 57296.
# No. Observations:               15178   AIC:                        -1.146e+05
# Df Residuals:                   15174   BIC:                        -1.146e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0003   5.08e-05      5.027      0.000       0.000       0.000
# Total Death         0.0002      0.005      0.037      0.971      -0.010       0.011
# Affected Family     0.7648      0.005    166.525      0.000       0.756       0.774
# Summer              0.0002      0.000      1.496      0.135   -5.11e-05       0.000
# ==============================================================================
# Omnibus:                    29010.489   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3644945283.440
# Skew:                          13.213   Prob(JB):                         0.00
# Kurtosis:                    2403.588   Cond. No.                         123.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Dropping houses_fully_destroyed as p-value is high.
X_train_new5 = X_train_new4.drop(["Total Death"], axis = 1)

# Adding a constant variable
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_new5)

lm = sm.OLS(y_train,X_train_new5).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Estimated Loss   R-squared:                       0.647
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                 1.388e+04
# Date:                Tue, 19 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:46:27   Log-Likelihood:                 57296.
# No. Observations:               15178   AIC:                        -1.146e+05
# Df Residuals:                   15175   BIC:                        -1.146e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.0003   5.08e-05      5.028      0.000       0.000       0.000
# Affected Family     0.7648      0.005    166.539      0.000       0.756       0.774
# Summer              0.0002      0.000      1.496      0.135   -5.12e-05       0.000
# ==============================================================================
# Omnibus:                    29010.462   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3644953055.831
# Skew:                          13.213   Prob(JB):                         0.00
# Kurtosis:                    2403.590   Cond. No.                         105.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Since all the remaining parameters have p-value less than 0.05, so we create equation as:
#   - Estimated Loss = 0.7611*Affected Family + 0.0054*houses_partially_destroyed + 0.0003

# %% [markdown]
# **Testing the Model**

# %%
df_test
# Out:
#        Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# 32651            0         12000.0                1                       0
# 12568            0       1004500.0                3                       0
# 1702             0       2900000.0                1                       1
# 8700             0        670000.0                1                       1
# 31987            0        200000.0                1                       1
# ...            ...             ...              ...                     ...
# 13030            0        600000.0                3                       3
# 36100            0         70000.0                2                       0
# 25258            0        100000.0                1                       0
# 9048             0       2150000.0                1                       1
# 23976            0        300000.0                2                       0
#
#        houses_partially_destroyed  Spring  Summer  Winter
# 32651                           0       0       0       1
# 12568                           0       1       0       0
# 1702                            0       1       0       0
# 8700                            0       0       1       0
# 31987                           0       0       0       1
# ...                           ...     ...     ...     ...
# 13030                           0       1       0       0
# 36100                           0       0       1       0
# 25258                           0       1       0       0
# 9048                            0       0       0       0
# 23976                           2       0       0       1
#
# [6506 rows x 8 columns]

# %%
num_vars = ['Total Death','Estimated Loss','Affected Family', 'houses_fully_destroyed','houses_partially_destroyed']

df_test[num_vars] = scaler.transform(df_test[num_vars])
df_test
# Out:
#        Total Death  Estimated Loss  Affected Family  houses_fully_destroyed  \
# 32651          0.0        0.000003         0.000058                0.000000
# 12568          0.0        0.000266         0.000173                0.000000
# 1702           0.0        0.000768         0.000058                0.000011
# 8700           0.0        0.000177         0.000058                0.000011
# 31987          0.0        0.000053         0.000058                0.000011
# ...            ...             ...              ...                     ...
# 13030          0.0        0.000159         0.000173                0.000033
# 36100          0.0        0.000019         0.000115                0.000000
# 25258          0.0        0.000026         0.000058                0.000000
# 9048           0.0        0.000569         0.000058                0.000011
# 23976          0.0        0.000079         0.000115                0.000000
#
#        houses_partially_destroyed  Spring  Summer  Winter
# 32651                    0.000000       0       0       1
# 12568                    0.000000       1       0       0
# 1702                     0.000000       1       0       0
# 8700                     0.000000       0       1       0
# 31987                    0.000000       0       0       1
# ...                           ...     ...     ...     ...
# 13030                    0.000000       1       0       0
# 36100                    0.000000       0       1       0
# 25258                    0.000000       1       0       0
# 9048                     0.000000       0       0       0
# 23976                    0.000114       0       0       1
#
# [6506 rows x 8 columns]

# %%
y_test = df_test.pop('Estimated Loss')
X_test = df_test
y_test
# Out:
# 32651    0.000003
# 12568    0.000266
# 1702     0.000768
# 8700     0.000177
# 31987    0.000053
#            ...
# 13030    0.000159
# 36100    0.000019
# 25258    0.000026
# 9048     0.000569
# 23976    0.000079
# Name: Estimated Loss, Length: 6506, dtype: float64

# %% [markdown]
# **Now let's use our model to make predictions.**

# %%
# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[['Affected Family','Summer']]

X_test_new
# Out:
#        Affected Family  Summer
# 32651         0.000058       0
# 12568         0.000173       0
# 1702          0.000058       0
# 8700          0.000058       1
# 31987         0.000058       0
# ...                ...     ...
# 13030         0.000173       0
# 36100         0.000115       1
# 25258         0.000058       0
# 9048          0.000058       0
# 23976         0.000115       0
#
# [6506 rows x 2 columns]

# %%
# Adding a constant variable
X_test_new = sm.add_constant(X_test_new)
X_test_new
# Out:
#        const  Affected Family  Summer
# 32651    1.0         0.000058       0
# 12568    1.0         0.000173       0
# 1702     1.0         0.000058       0
# 8700     1.0         0.000058       1
# 31987    1.0         0.000058       0
# ...      ...              ...     ...
# 13030    1.0         0.000173       0
# 36100    1.0         0.000115       1
# 25258    1.0         0.000058       0
# 9048     1.0         0.000058       0
# 23976    1.0         0.000115       0
#
# [6506 rows x 3 columns]

# %%
# Making predictions
y_pred = lm.predict(X_test_new)
y_pred
# Out:
# 32651    0.000299
# 12568    0.000387
# 1702     0.000299
# 8700     0.000464
# 31987    0.000299
#            ...
# 13030    0.000387
# 36100    0.000508
# 25258    0.000299
# 9048     0.000299
# 23976    0.000343
# Length: 6506, dtype: float64

# %%
#Original normalized expenses
y_test
# Out:
# 32651    0.000003
# 12568    0.000266
# 1702     0.000768
# 8700     0.000177
# 31987    0.000053
#            ...
# 13030    0.000159
# 36100    0.000019
# 25258    0.000026
# 9048     0.000569
# 23976    0.000079
# Name: Estimated Loss, Length: 6506, dtype: float64

# %% [markdown]
# **Testing the Accuracy**

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.12235553486197426

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')

# %% [markdown]
# # Conclusion based on Linear Regression
# - The accuracy regression is mere 12.2%, this indicates that the parameters in the dataset has almost no linear dependencies.
# - This model cannot accurately predict the prediciton of estimated loss by any of the above parameters.
#
# # Recommendation
# - It is advised that the dataset be analyzed by other methods of regression such as polynomials, cubic, parabolic and even exponential.
